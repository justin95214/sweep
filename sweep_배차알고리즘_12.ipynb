# %% [markdown]
# <a href="https://colab.research.google.com/github/justin95214/sweep/blob/main/sweep_%EB%B0%B0%EC%B0%A8%EC%95%8C%EA%B3%A0%EB%A6%AC%EC%A6%98_12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# sweep알고리즘
#
# copyright file :sweep 배차알고리즘 코드
#
#
# Author: Duhyeuk Chang, Soochan Choi
#
#
# Copyright (c) Developer Express. All rights reserved.

# %%
#!git clone https://github.com/justin95214/sweep.git

# %% [markdown]
# **1. 구글드라이브 연결하기**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# **2. 프로그램 구동**

# %% [markdown]
# **2-1. DP 업로드**

# %%
import numpy as np
import pandas as pd

import io
from google.colab import files
myfile = files.upload()
# Out:
#      <input type="file" id="files-ed7ee9f8-7ba1-4820-8027-e190cf40e341" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ed7ee9f8-7ba1-4820-8027-e190cf40e341">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving DP_raw.xlsx to DP_raw.xlsx

# %%
df_DP = pd.read_excel(io.BytesIO(myfile['DP_raw.xlsx']))

# %% [markdown]
# **2-2. 거래처 파일 PR_week 업로드**

# %%
myfile = files.upload()
# Out:
#      <input type="file" id="files-be7ce45d-da2a-4caf-93c2-607b3fa21555" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-be7ce45d-da2a-4caf-93c2-607b3fa21555">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving PR_week.xlsx to PR_week.xlsx

# %%
df_client = pd.read_excel(io.BytesIO(myfile['PR_week.xlsx']))

# %% [markdown]
# **2-3. 거래처 파일 조건 시트 업로드**

# %%
myfile = files.upload()
# Out:
#      <input type="file" id="files-fbd866c4-433a-401e-8954-b20156da189c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-fbd866c4-433a-401e-8954-b20156da189c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving variable.xlsx to variable.xlsx

# %%
df_info  = pd.read_excel(io.BytesIO(myfile['variable.xlsx']))

# %% [markdown]
# **3. 센터 DP Info 확인하기**

# %%
df_DP.info
# Out:
# <bound method DataFrame.info of           DP                    주소  Longitude    Latitude  구간
# 0  특수사업부(오산)     경기도 화성시 금곡로 63-28  37.167724  127.077165 NaN
# 1  특수사업부(영남)  경상남도 김해시 어방동 1062-21  35.236969  128.905964 NaN>

# %%
week_num =['월','화','수','목','금','토','일']
for day in week_num:
  # %mkdir /content/drive/MyDrive/$day

# %mkdir /content/drive/MyDrive/Integrated_analysis
# Out:
# mkdir: cannot create directory ‘/content/drive/MyDrive/월’: File exists
# mkdir: cannot create directory ‘/content/drive/MyDrive/화’: File exists
# mkdir: cannot create directory ‘/content/drive/MyDrive/수’: File exists
# mkdir: cannot create directory ‘/content/drive/MyDrive/목’: File exists
# mkdir: cannot create directory ‘/content/drive/MyDrive/금’: File exists
# mkdir: cannot create directory ‘/content/drive/MyDrive/토’: File exists
# mkdir: cannot create directory ‘/content/drive/MyDrive/일’: File exists
# mkdir: cannot create directory ‘/content/drive/MyDrive/Integrated_analysis’: File exists

# %%
# df-client info
#df_client = pd.read_excel('PR_week.xlsx')
#print(df_client.head(10))

# DP address
#df_DP = pd.read_excel('DP_raw.xlsx')
#print(df_DP.head(5))
df_client = pd.merge(left=df_client, right=df_DP, on="DP", how="right")
df_client = df_client
# DF truck & time info df
#df_info = pd.read_excel('sheet_4.xlsx')
# merge the info
info_col=df_info.columns[1:]

#df_client[info_col] = df_info[info_col].iloc[0]
df_client = pd.merge(left=df_client, right=df_info, on="DP", how="right")

# %% [markdown]
# # 새 섹션

# %%
week_num =['월','화','수','목','금','토','일']

at_once = []
total_max = []
# change the day
for day in week_num:
	how_long_list=[]
	total1_list =[]
	print("############################################################################################################\n")
	#Per DP, get the client info
	for DF_element in  df_DP['DP'].values.tolist():
		print("@@@@@@@@@@@@@@@@@@@@@@@@		["+ DF_element+"/"+day+"]		@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@\n")
		#지역 요일 별 df
		temp_df = df_client.loc[df_client['DP']==DF_element]
		print("@@@@@@@@@@@@@@@@@@@@@@@@			shape :", temp_df.shape)
		print("@@@@@@@@@@@@@@@@@@@@@@@@               small shape :", temp_df.loc[df_client[day]==1].shape)
		filter_columns = list(set(temp_df.columns.values.tolist())- set(week_num))
		filter_columns.append(day)
		temp_df = temp_df[filter_columns]	
		print(temp_df.head(5))
		temp_df['stopby'] = 0
		#temp_df =temp_df.dropna(axis=0)
		print("지역 요일 별 df shape : ",temp_df.shape)
		#print(temp_df.head(5))
		#stopby check!!
		#temp_df.to_csv("./result/test_"+DF_element+"_"+day+".csv",index=False ,encoding='utf-8-sig')
		# how many truck we need!
		# how many back to DP
		Point_list =['DP']
		Rest_time_list =[]
		Rest_Stock_list=[]
		distance = 0
		#temp_df.astype('float')
		print(temp_df.columns)
		print(temp_df.head(4))
		print(temp_df['대당 적재능력(box)'].iloc[0])
		Rest_Stock_list.append(temp_df.iloc[0]['대당 적재능력(box)'])
		Rest_time_list.append(temp_df.iloc[0]['대당 운행시간(분)'])
		current_point = 'DP'
		truck_list = []
		check = 0
		up_time = 0
		d_list=[]
		time_list=[]
		one_truck_list=[]
		Max_row =0
		col_list=[]
		T_time_list = []
		DP_count = []
		car_num =0
		how_many_car_list = []

		while(len(temp_df.loc[temp_df['stopby']==0]) >0):
			print("Point_list : ", Point_list)
			print("@@@@@@@@@@@@@@@@@@@@@@@@               check the stopby :", temp_df.loc[temp_df['stopby']==0].shape)
			#print("---------------------------")
			#print("Time list :", Rest_time_list)
			#print("---------------------------")
			#print("Stock list :", Rest_Stock_list)
			#print("---------------------------")
			#check = check+1
			print("---------------------------------------------------------------------------------------------------------------------------------\n")
			if current_point =='DP':

				temp_df['DP_x곡률값']=temp_df['Latitude']*3600
				temp_df['DP_y곡률값']=temp_df['Longitude']*3600
	
				#client curvature value
				temp_df['x곡률값']=temp_df['경도(X좌표)']*3600
				temp_df['y곡률값']=temp_df['위도(Y좌표)']*3600

				temp_df['DP_위도거리']= abs(temp_df['x곡률값']-temp_df['DP_y곡률값'])*0.0245
				temp_df['DP_경도거리']= abs(temp_df['y곡률값']-temp_df['DP_x곡률값'])*0.0306
				temp_df['DP_운행거리'] = temp_df['DP_위도거리']+temp_df['DP_경도거리']

				#최초와 중간 회차 뒤에 경우 
				Max_distance_row = temp_df[temp_df['stopby']==0].sort_values(by='DP_운행거리', ascending=False).iloc[0]
				#print(">>운행거리 :", Max_distance_row['DP_운행거리'])

				#현재 위치 변경
				current_point = Max_distance_row['code']
				#print(check,"거리로 선정 Client: ",Max_distance_row['DP_운행거리'],current_point)
				print(">>",current_point)

				#장소 리스트 업데이트 
				Point_list.append(current_point)

				#stopby =1 check
				temp_df.loc[(temp_df['code']==current_point),'stopby']=1

				#적재량 리스트 업데이트
				current_point_stock = Max_distance_row[day].tolist()

				Rest_Stock_list.append(Rest_Stock_list[-1]-current_point_stock)

				print(" >> currrent_p : ",current_point,"	current_stock : ",current_point_stock)
				dist = temp_df.loc[temp_df['code']==current_point]['DP_운행거리'].values.tolist()[0]
				fast = temp_df.loc[temp_df['code']==current_point]['평균 운행 속도(km/h)'].values.tolist()[0]
				time =  (dist / fast)*60
				print("dist :	",dist,"/ fast :	",fast,"/ time :	",time)
							

				
				#남은 시간 리스트  업데이트 
				#소요 시간 = 상차 + [DP-현재 위치]이동시간 + 하차  
				Rest_time_list.append(Rest_time_list[-1] - time - temp_df.loc[temp_df['code']==current_point]['상차시간(분)'].values.tolist()[0] - temp_df.loc[temp_df['code']==current_point]['하차시간(분)'].values.tolist()[0])
				# 누적 시간 업데이트
				up_time= up_time+time+temp_df.loc[temp_df['code']==current_point]['하차시간(분)'].values.tolist()[0] +temp_df.loc[temp_df['code']==current_point]['하차시간(분)'].values.tolist()[0]
				# 누적 거리 업데이트
				
				# 기존 거리 = 기존 거리 + [DP-현재 위치]이동시간
				distance =distance+dist
				#print("거리",temp_df.loc[temp_df['code']==current_point]['DP_운행거리'].values.tolist()[0],"  / 속도 :",temp_df.loc[temp_df['code']==current_point]['평균 운행 속도(km/h)'].values.tolist()[0])
				#print("소요시간 :",(temp_df.loc[temp_df['code']==current_point]['DP_운행거리'].values.tolist()[0]/temp_df.loc[temp_df['code']==current_point]['평균 운행 속도(km/h)'].values.tolist()[0])*60)
				next_check_time = (temp_df.loc[temp_df['code']==current_point]['DP_운행거리'].values.tolist()[0]/temp_df.loc[temp_df['code']==current_point]['평균 운행 속도(km/h)'].values.tolist()[0])*60
				# 현재 지점에서 DP까지 시간 여유
				print("누적거리 :   ",distance,"/ 누적시간  :        ",up_time,"/ time :        ",next_check_time , "possible stock :	",Rest_Stock_list[-1])
				print("Point_list : ", Point_list)
				print("From :",Point_list[-2],"To :",Point_list[-1])

			elif current_point !='DP':
				#print(">>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>y!!!!!!DP")
				#거래처 위치 
				temp_df['x곡률값']=temp_df['경도(X좌표)']*3600
				temp_df['y곡률값']=temp_df['위도(Y좌표)']*3600

				#현재 위치 (DP >> 현재 위치 
				temp_df[current_point+'_x곡률값']=temp_df.loc[temp_df['code']==Point_list[-1]]['경도(X좌표)'].values.tolist()[0]*3600
				temp_df[current_point+'_y곡률값']=temp_df.loc[temp_df['code']==Point_list[-1]]['위도(Y좌표)'].values.tolist()[0]*3600

				#현재 위치와 거래처간의 계산
				temp_df[current_point+'위도거리']= abs(temp_df['x곡률값'] -temp_df[current_point+'_x곡률값'] )  *0.0245
				temp_df[current_point+'경도거리']= abs(temp_df['y곡률값'] -temp_df[current_point+'_y곡률값'] )  *0.0306
				temp_df[current_point+'운행거리'] = temp_df[current_point+'위도거리']+temp_df[current_point+'경도거리']
				#print(temp_df.head(1))			

				#print(temp_df.head(5))
				temp_df['각도']= np.degrees(np.arctan(temp_df[current_point+'위도거리']/temp_df[current_point+'경도거리']))

				#print("주행거리 : ",lowest_degree_row[current_point+'운행거리'])
				#distance =distance+ lowest_degree_row[current_point+'운행거리']


				#각도가 최적인 것을 선택
				#lowest_degree_row = temp_df[temp_df['stopby']==0].sort_values(by= '각도').iloc[0]
				tdf= temp_df[temp_df['stopby']==0]
				tdf = tdf.copy()

				lowest_degree_row = tdf.sort_values(by=current_point+'운행거리')
				print("hhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhh")
				#print(lowest_degree_row.head(3))

				lowest_degree_row =  lowest_degree_row.iloc[0]

				dist = lowest_degree_row[current_point+'운행거리'].tolist()
				fast = lowest_degree_row['평균 운행 속도(km/h)'].tolist()
				time =  (dist / fast)*60
				print("dist :   ",dist,"/ fast :        ",fast,"/ time :        ",time)


				#현재f 위치 변경
				current_point = lowest_degree_row['code']
				Point_list.append(current_point)

				# stopby =1 check
				temp_df.loc[(temp_df['code']==current_point),'stopby']=1
				
				#current_point = lowest_degree_row['code']

				#남은시간 리스트 업데이트 
				#  마지막 남은시간- [ 기존거래처 - 갱신 거래처]이동거리 - 하차				
				Rest_time_list.append((Rest_time_list[-1] -time - temp_df.loc[temp_df['code']==current_point]['하차시간(분)'].values.tolist()[0]))

				# 누적 시간 업데이트 
				get_ff_time = temp_df.loc[temp_df['code']==current_point]['하차시간(분)'].values.tolist()[0]

				up_time= up_time + time + get_ff_time

				distance =distance+dist

				current_point_stock= lowest_degree_row[day].tolist()
				#남은 적재량 리스트 업데이트 
				Rest_Stock_list.append(Rest_Stock_list[-1]-current_point_stock)
				#print(" ++ currrent_p : ",current_point,"   current_stock : ",current_point_stock)
				print("누적거리 :   ",distance,"/ 누적시간  :        ",up_time, "/ Rest_time :	 ",Rest_time_list[-1],  " / possible stock :,",Rest_Stock_list[-1],"/ possible time :        ",next_check_time)
				print("From :",Point_list[-2],"To :",Point_list[-1])

				next_check_time = (temp_df.loc[temp_df['code']==current_point]['DP_운행거리'].values.tolist()[0]/temp_df.loc[temp_df['code']==current_point]['평균 운행 속도(km/h)'].values.tolist()[0])*60


			d_list.append(distance)

			if  Rest_time_list[-1]- next_check_time>0 and Rest_Stock_list[-1] >0  and up_time<360:
				print("조건 1",Rest_time_list[-1]- next_check_time,Rest_Stock_list[-1])
				#print("<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<",up_time)
				if temp_df.loc[temp_df['stopby']==0].shape[0] ==0:
					truck_list.append(Point_list)
					col_list.append(len(Point_list))
					one_truck_list.append(len(Point_list)-Point_list.count("DP"))
					time_list.append(distance)
					T_time_list.append(up_time)

					DP_count.append(Point_list.count("DP")-1)
					car_num= car_num+1
					how_many_car_list.append("No. "+str(car_num))


			
				continue
			elif Rest_time_list[-1]- next_check_time>0 and Rest_Stock_list[-1] <=0 and up_time <360:
				print("조건 2",Rest_time_list[-1]- next_check_time,Rest_Stock_list[-1])
				# 여유시간이 충분한데 capa 가 없을 때 
				current_point ='DP'
				# 회차 하고 다시 다음 회전을 위한 상차 
				Rest_time_list.append((Rest_time_list[-1]- next_check_time - temp_df.iloc[0]['상차시간(분)']))
				
				up_time = up_time+next_check_time+temp_df.iloc[0]['상차시간(분)']
				Point_list.append(current_point)
				Rest_Stock_list.append(temp_df.iloc[0]['대당 적재능력(box)'])
			   	#distance = distance + temp_df.loc[temp_df['code']==current_point]['DP_운행거리'].values.tolist()[0]
				d_list.append(distance)
				print("					<<<<<<<<<<<<<회차 현황 : >>>>>>>>>>>>>>>>>>\n")
				print("누적거리 :   ",distance,"/ 누적시간  :        ",up_time, "/ Rest_time :   ",Rest_time_list[-1],  " / possible stock :,",Rest_Stock_list[-1],"/ possible time :        ",next_check_time)
				if up_time <360 or Rest_time_list[-1] > 0:
					print("*************************************************************************************************")
					#truck_list.append(Point_list)
					print("here here here ")
					if len(temp_df.loc[temp_df['stopby']==0]) <1:
						print("eeeeeeeeeeeeeeeweeeeeeeeeeeeeeeeeeeeeeeeewwwwwwwwwwwwwwwwwwe")
						truck_list.append(Point_list) 
						col_list.append(len(Point_list))
						one_truck_list.append(len(Point_list)-Point_list.count("DP"))
						time_list.append(distance)
						T_time_list.append(up_time)
						DP_count.append(Point_list.count("DP")-1)
						car_num= car_num+1
						how_many_car_list.append("No. "+str(car_num))
				
				elif up_time > 360 or Rest_time_list[-1] < 0 :
					
					print(" >>>>>>>>>>>>>>>>>>>>>회차 시 누적 시간 이 360 초과 여서 운행 종료 <<<<<<<<<<<<<<<<<<<<<<<<<<<\n")

					truck_list.append(Point_list)
					col_list.append(len(Point_list))
					one_truck_list.append(len(Point_list)-Point_list.count("DP"))
					time_list.append(distance)
					T_time_list.append(up_time)
					DP_count.append(Point_list.count("DP")-1)
					car_num= car_num+1
					how_many_car_list.append("No. "+str(car_num))

					current_point = 'DP'
					Point_list = ['DP']
					Rest_Stock_list = [temp_df.iloc[0]['대당 적재능력(box)']]
					Rest_time_list = [temp_df.iloc[0]['대당 운행시간(분)']]
					up_time =0


				#elif up_time <360 or Rest_time_list[-1] > 0 and len(temp_df.loc[temp_df['stopby']==0]) < 1:
					#truck_list.append(Point_list)


			elif len(temp_df.loc[temp_df['stopby']==0]) ==1:
				print("조건 4 :1개 남음 \n")
				continue


				# 여유시간이 없을 때 
			elif Rest_time_list[-1]- next_check_time <0 or Rest_time_list[-1]>0: 
				print("조건 3",Rest_time_list[-1]- next_check_time,Rest_Stock_list[-1])
				print("Left  0 count :",len(temp_df.loc[temp_df['stopby']==0]),"zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz")

				if up_time < 360 and len(temp_df.loc[temp_df['stopby']==0]) >1:
				# 여유시간이 없을 때 마지막 거래처는 갔다온다

					#거래처 위치
					temp_df['x곡률값']=temp_df['경도(X좌표)']*3600
					temp_df['y곡률값']=temp_df['위도(Y좌표)']*3600

					#현재 위치 (Cient >> 마지막 복귀
					temp_df[current_point+'_x곡률값']=temp_df.loc[temp_df['code']==Point_list[-1]]['경도(X좌표)'].values.tolist()[0]*3600
					temp_df[current_point+'_y곡률값']=temp_df.loc[temp_df['code']==Point_list[-1]]['위도(Y좌표)'].values.tolist()[0]*3600

					#현재 위치와 거래처간의 계산
					temp_df[current_point+'위도거리']= abs(temp_df['x곡률값'] -temp_df[current_point+'_x곡률값'] )  *0.0245
					temp_df[current_point+'경도거리']= abs(temp_df['y곡률값'] -temp_df[current_point+'_y곡률값'] )  *0.0306
					temp_df[current_point+'운행거리'] = temp_df[current_point+'위도거리']+temp_df[current_point+'경도거리']

					#print(temp_df.head(5))
					temp_df['각도']= np.degrees(np.arctan(temp_df[current_point+'위도거리']/temp_df[current_point+'경도거리']))

					#print("주행거리 : ",lowest_degree_row[current_point+'운행거리'])
					#distance =distance+ lowest_degree_row[current_point+'운행거리']


					#각도가 최적인 것을 선택
					#lowest_degree_row = temp_df[temp_df['stopby']==0].sort_values(by='각도').iloc[0]

					tdf= temp_df[temp_df['stopby']==0]
					tdf = tdf.copy()
					lowest_degree_row = tdf.sort_values(by=current_point+'운행거리')
					lowest_degree_row =  lowest_degree_row.iloc[0]

	
					dist = lowest_degree_row[current_point+'운행거리'].tolist()
					fast = lowest_degree_row['평균 운행 속도(km/h)'].tolist()
					time =  (dist / fast)*60
					print("dist :   ",dist,"/ fast :        ",fast,"/ time :        ",time)


					#현재 위치 변경
					current_point = lowest_degree_row['code']
					Point_list.append(current_point)
					print("Point list : ", Point_list)
					# stopby =1 check
					temp_df.loc[(temp_df['code']==current_point),'stopby']=1

					#current_point = lowest_degree_row['code']

					#남은시간 리스트 업데이트
					#  마지막 남은시간- [ 기존거래처 - 갱신 거래처]이동거리 - 하차
					Rest_time_list.append(Rest_time_list[-1] -time - temp_df.loc[temp_df['code']==current_point]['하차시간(분)'].values.tolist()[0])

					# 누적 시간 업데이트
					get_ff_time = temp_df.loc[temp_df['code']==current_point]['하차시간(분)'].values.tolist()[0]

					up_time= up_time + time + get_ff_time
					distance =distance+dist

					current_point_stock= lowest_degree_row[day].tolist()
					#남은 적재량 리스트 업데이트
					Rest_Stock_list.append(Rest_Stock_list[-1]-current_point_stock)
					#print(" ++ currrent_p : ",current_point,"   current_stock : ",current_point_stock)
					print("누적거리 :   ",distance,"/ 누적시간  :        ",up_time, "/ Rest_time :   ",Rest_time_list[-1], "/ possible stock :,",Rest_Stock_list[-1],"  / possible time :        ",next_check_time)
					print("From :",Point_list[-2],"To :",Point_list[-1])

					next_check_time = (temp_df.loc[temp_df['code']==current_point]['DP_운행거리'].values.tolist()[0]/temp_df.loc[temp_df['code']==current_point]['평균 운행 속도(km/h)'].values.tolist()[0])*60
					distance= distance+temp_df.loc[temp_df['code']==current_point]['DP_운행거리'].values.tolist()[0]
					# 회차  >>DP
					Rest_time_list.append(Rest_time_list[-1]-next_check_time)
					up_time= up_time+ next_check_time
					print("누적거리 :   ",distance,"/ 누적시간  :        ",up_time, "/ Rest_time :   ",Rest_time_list[-1], " / possible stock :,",Rest_Stock_list[-1],">> 복귀 완료 \n")
					print("\n")
					
				else:
					print(" >>>>>>>>>>>>>>>>>>>>>회차 시 누적 시간 이 360 초과 여서 운행 종료 <<<<<<<<<<<<<<<<<<<<<<<<<<<\n")
				

				# 회차만 
				Rest_time_list.append(Rest_time_list[-1]- next_check_time)
				print("VVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVV",distance)
				truck_list.append(Point_list)
				col_list.append(len(Point_list))
				one_truck_list.append(len(Point_list)-Point_list.count("DP"))
				time_list.append(distance)
				T_time_list.append(up_time)

				current_point = 'DP'
				print("From :",Point_list[-2],"To :", current_point)

				Rest_Stock_list = [temp_df.iloc[0]['대당 적재능력(box)']]
				Rest_time_list = [temp_df.iloc[0]['대당 운행시간(분)']]
				DP_count.append(Point_list.count("DP")-1)
				Point_list = ['DP']
				#one_truck_list.append(len(Point_list))
				distnace = 0
				up_time =0
				car_num= car_num+1
				how_many_car_list.append("No. "+str(car_num))


			if up_time> 360:
				distance =0
				print("here i am")
				print(">>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>",distance)
				#one_truck_list.append(len(Point_list))
				#truck_list.append(Point_list)
				current_point = 'DP'
				Rest_Stock_list = [temp_df.iloc[0]['대당 적재능력(box)']]
				Rest_time_list = [temp_df.iloc[0]['대당 운행시간(분)']]
				up_time =0



		
		Max_row = max(col_list)
		temp_df.to_csv("temp1.csv", index=False, encoding='utf-8-sig')
		result0 = pd.DataFrame(how_many_car_list, columns=["Truck Count"])		
		result0["Region"]= DF_element
		result0["Week"]= day
		result1 = pd.DataFrame(truck_list,columns = ["Client-"+str(i) for i in range(Max_row)])
		result2 = pd.DataFrame(one_truck_list,columns=["Client Count"])
		result3 = pd.DataFrame(time_list,columns=["누적 KM"])
		per_dist =[]
		take = result3["누적 KM"].values.tolist()
		for i in range(0, len(take)):
			
			if i == 0:
				per_dist.append(take[i])
			else:
				per_dist.append((take[i]-take[i-1]))

		result3 = pd.DataFrame(per_dist,columns=["KM"])
		result5 = pd.DataFrame(T_time_list,columns=["Time"])
		result6 = pd.DataFrame(DP_count,columns=["DP를 몇 번"])
		
		result4 = pd.concat([result0,result5,result3,result2,result6, result1],axis=1)
		result4.to_csv("/content/drive/MyDrive/"+day+"/"+DF_element+day+"complete.csv",encoding='utf-8-sig', index=False)
		#print(result)
		for f_row in result4.values.tolist():
			print(f_row)
			how_long_list.append(len(f_row)-6)
			total1_list.append(f_row)
	print("max :", max(how_long_list))
	t_colums_list = ["Truck Count","Region","Week","Time","KM","Client Count"]
	client_list = ["Client-"+str(i) for i in range(max(how_long_list))]

	t_colums_list= t_colums_list + client_list
	print(t_colums_list)
	result_t =  pd.DataFrame(total1_list, columns = t_colums_list)
	result_t.to_csv("/content/drive/MyDrive/Integrated_analysis/"+"Interal_Region"+day+"analysis.csv"+"Interal_Region"+day+"analysis.csv",encoding='utf-8-sig', index=False)
	
	total_max.append(max(how_long_list))
	for i in total1_list:
		at_once.append(i)

DR_columns_list = ["Truck Count","Region","Week","Time","KM","Client Count"]
client_list1 = ["Position-"+str(i) for i in range(max(total_max))]
DR_columns_list = DR_columns_list + client_list1 
DR_df = pd.DataFrame(at_once, columns=DR_columns_list)

DR_df.to_csv("/content/drive/MyDrive/Integrated_analysis/"+"Interal_Region_Week_analysis.csv",encoding='utf-8-sig', index=False)
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# max : 4
# ['Truck Count', 'Region', 'Week', 'Time', 'KM', 'Client Count', 'Client-0', 'Client-1', 'Client-2', 'Client-3']
# ############################################################################################################
#
# @@@@@@@@@@@@@@@@@@@@@@@@		[특수사업부(오산)/금]		@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
#
# @@@@@@@@@@@@@@@@@@@@@@@@			shape : (102, 24)
# @@@@@@@@@@@@@@@@@@@@@@@@               small shape : (0, 24)
#    대당 적재능력(box)  구분_x  대당 운행시간(분)              Addressline    Latitude  \
# 0         100.0  주 1회       400.0    경기도 성남시 중원구 상대원동 64    127.077165
# 1         100.0  주 1회       400.0    경기도 성남시 중원구 순환로 222    127.077165
# 2         100.0  주 1회       400.0  인천광역시 계양구 벌말로 573번길 9    127.077165
# 3         100.0  주 1회       400.0  서울특별시 강동구 성내동 501-11     127.077165
# 4         100.0  주 1회       400.0  서울특별시 강서구 곰달래로59길 60     127.077165
#
#   citydistrict  상차시간(분)    경도(X좌표)                 주소             code  \
# 0      경기도 성남시      0.0  37.443574  경기도 화성시 금곡로 63-28    (주)크린토피아 성남지사
# 1      경기도 성남시      0.0  37.443574  경기도 화성시 금곡로 63-28  (주)크린토피아 오산직영지사
# 2    인천광역시 계양구      0.0  37.579845  경기도 화성시 금곡로 63-28             가양지사
# 3    서울특별시 강동구      0.0  37.531551  경기도 화성시 금곡로 63-28             강동지사
# 4    서울특별시 강서구      0.0  37.534969  경기도 화성시 금곡로 63-28             강서지사
#
#      구분_y  하차시간(분)     위도(Y좌표)  구간  평균 운행 속도(km/h)  Longitude         DP   금
# 0  기준 데이터      5.0  127.179662 NaN            50.0  37.167724  특수사업부(오산) NaN
# 1  기준 데이터      5.0  127.179662 NaN            50.0  37.167724  특수사업부(오산) NaN
# 2  기준 데이터      5.0  126.778110 NaN            50.0  37.167724  특수사업부(오산) NaN
# 3  기준 데이터      5.0  127.131530 NaN            50.0  37.167724  특수사업부(오산) NaN
# 4  기준 데이터      5.0  126.862936 NaN            50.0  37.167724  특수사업부(오산) NaN
# 지역 요일 별 df shape :  (102, 19)
# Index(['대당 적재능력(box)', '구분_x', '대당 운행시간(분)', 'Addressline', 'Latitude',
#        'citydistrict', '상차시간(분)', '경도(X좌표)', '주소', 'code', '구분_y', '하차시간(분)',
#        '위도(Y좌표)', '구간', '평균 운행 속도(km/h)', 'Longitude', 'DP', '금', 'stopby'],
#       dtype='object')
#    대당 적재능력(box)  구분_x  대당 운행시간(분)              Addressline    Latitude  \
# 0         100.0  주 1회       400.0    경기도 성남시 중원구 상대원동 64    127.077165
# 1         100.0  주 1회       400.0    경기도 성남시 중원구 순환로 222    127.077165
# 2         100.0  주 1회       400.0  인천광역시 계양구 벌말로 573번길 9    127.077165
# 3         100.0  주 1회       400.0  서울특별시 강동구 성내동 501-11     127.077165
#
#   citydistrict  상차시간(분)    경도(X좌표)                 주소             code  \
# 0      경기도 성남시      0.0  37.443574  경기도 화성시 금곡로 63-28    (주)크린토피아 성남지사
# 1      경기도 성남시      0.0  37.443574  경기도 화성시 금곡로 63-28  (주)크린토피아 오산직영지사
# 2    인천광역시 계양구      0.0  37.579845  경기도 화성시 금곡로 63-28             가양지사
# 3    서울특별시 강동구      0.0  37.531551  경기도 화성시 금곡로 63-28             강동지사
#
#      구분_y  하차시간(분)     위도(Y좌표)  구간  평균 운행 속도(km/h)  Longitude         DP   금  \
# 0  기준 데이터      5.0  127.179662 NaN            50.0  37.167724  특수사업부(오산) NaN
# 1  기준 데이터      5.0  127.179662 NaN            50.0  37.167724  특수사업부(오산) NaN
# 2  기준 데이터      5.0  126.778110 NaN            50.0  37.167724  특수사업부(오산) NaN
# 3  기준 데이터      5.0  127.131530 NaN            50.0  37.167724  특수사업부(오산) NaN
#
#    stopby
# 0       0
# 1       0
# 2       0
# 3       0
# 100.0
# Point_list :  ['DP']
# @@@@@@@@@@@@@@@@@@@@@@@@               check the stopby : (102, 19)
# ---------------------------------------------------------------------------------------------------------------------------------
#
# >> 춘천지사
#  >> currrent_p :  춘천지사 	current_stock :  nan
# dist :	 132.72646992043548 / fast :	 50.0 / time :	 159.27176390452257
# 누적거리 :    132.72646992043548 / 누적시간  :         169.27176390452257 / time :         159.27176390452257 possible stock :	 nan
# Point_list :  ['DP', '춘천지사']
# From : DP To : 춘천지사
# 조건 3 76.45647219095486 nan
# Left  0 count : 101 zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz
# dist :    67.76670649726782 / fast :         50.0 / time :         81.32004779672138
# Point list :  ['DP', '춘천지사', '남양주지사']
# 누적거리 :    200.4931764177033 / 누적시간  :         255.59181170124396 / Rest_time :    149.40818829875604 / possible stock :, nan   / possible time :         159.27176390452257
# From : 춘천지사 To : 남양주지사
# 누적거리 :    265.45293984087095 / 누적시간  :         333.54352780904514 / Rest_time :    71.45647219095484  / possible stock :, nan >> 복귀 완료
#
#
#
# VVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVV 265.45293984087095
# From : 춘천지사 To : DP
# Point_list :  ['DP']
# @@@@@@@@@@@@@@@@@@@@@@@@               check the stopby : (100, 32)
# ---------------------------------------------------------------------------------------------------------------------------------
#
# >> 서대전지사
#  >> currrent_p :  서대전지사 	current_stock :  nan
# dist :	 111.2099892489874 / fast :	 50.0 / time :	 133.45198709878488
# 누적거리 :    376.6629290898584 / 누적시간  :         143.45198709878488 / time :         133.45198709878488 possible stock :	 nan
# Point_list :  ['DP', '서대전지사']
# From : DP To : 서대전지사
# 조건 3 128.0960258024302 nan
# Left  0 count : 99 zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz
# dist :    6.85363361810281 / fast :         50.0 / time :         8.224360341723372
# Point list :  ['DP', '서대전지사', '남대전지사']
# 누적거리 :    383.5165627079612 / 누적시간  :         156.67634744050827 / Rest_time :    248.3236525594917 / possible stock :, nan   / possible time :         133.45198709878488
# From : 서대전지사 To : 남대전지사
# 누적거리 :    492.11240300353217 / 누적시간  :         286.9913557951934 / Rest_time :    118.00864420480656  / possible stock :, nan >> 복귀 완료
#
#
#
# VVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVV 492.11240300353217
# From : 서대전지사 To : DP
# Point_list :  ['DP']
# @@@@@@@@@@@@@@@@@@@@@@@@               check the stopby : (98, 37)
# ---------------------------------------------------------------------------------------------------------------------------------
#
# >> 원주지사
#  >> currrent_p :  원주지사 	current_stock :  nan
# dist :	 110.19879484209794 / fast :	 50.0 / time :	 132.23855381051752
# 누적거리 :    602.3111978456301 / 누적시간  :         142.23855381051752 / time :         132.23855381051752 possible stock :	 nan
# Point_list :  ['DP', '원주지사']
# From : DP To : 원주지사
# 조건 3 130.522892378965 nan
# Left  0 count : 97 zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz
# dist :    56.866675525522886 / fast :         50.0 / time :         68.24001063062747
# Point list :  ['DP', '원주지사', '이천지사']
# 누적거리 :    659.1778733711529 / 누적시간  :         215.47856444114498 / Rest_time :    189.52143555885505 / possible stock :, nan   / possible time :         132.23855381051752
# From : 원주지사 To : 이천지사
# 누적거리 :    712.509992687728 / 누적시간  :         279.47710762103503 / Rest_time :    125.52289237896498  / possible stock :, nan >> 복귀 완료
#
#
#
# VVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVV 712.509992687728
# From : 원주지사 To : DP
# Point_list :  ['DP']
# @@@@@@@@@@@@@@@@@@@@@@@@               check the stopby : (96, 42)
# ---------------------------------------------------------------------------------------------------------------------------------
#
# >> 대전지사
#  >> currrent_p :  대전지사 	current_stock :  nan
# dist :	 109.84443571805181 / fast :	 50.0 / time :	 131.81332286166216
# 누적거리 :    822.3544284057798 / 누적시간  :         141.81332286166216 / time :         131.81332286166216 possible stock :	 nan
# Point_list :  ['DP', '대전지사']
# From : DP To : 대전지사
# 조건 3 131.37335427667566 nan
# Left  0 count : 95 zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz
# dist :    18.242338659587894 / fast :         50.0 / time :         21.890806391505475
# Point list :  ['DP', '대전지사', '대전유성지사']
# 누적거리 :    840.5967670653677 / 누적시간  :         168.70412925316762 / Rest_time :    236.29587074683235 / possible stock :, nan   / possible time :         131.81332286166216
# From : 대전지사 To : 대전유성지사
# 누적거리 :    943.3365216133926 / 누적시간  :         291.99183471079755 / Rest_time :    113.00816528920241  / possible stock :, nan >> 복귀 완료
#
#
#
# VVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVV 943.3365216133926
# From : 대전지사 To : DP
# Point_list :  ['DP']
# @@@@@@@@@@@@@@@@@@@@@@@@               check the stopby : (94, 47)
# ---------------------------------------------------------------------------------------------------------------------------------
#
# >> 남청주지사
#  >> currrent_p :  남청주지사 	current_stock :  nan
# dist :	 91.65921513668177 / fast :	 50.0 / time :	 109.99105816401813
# 누적거리 :    1034.9957367500745 / 누적시간  :         119.99105816401813 / time :         109.99105816401813 possible stock :	 nan
# Point_list :  ['DP', '남청주지사']
# From : DP To : 남청주지사
# 조건 3 175.01788367196377 nan
# Left  0 count : 93 zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz
# dist :    4.4271943417729345 / fast :         50.0 / time :         5.3126332101275215
# Point list :  ['DP', '남청주지사', '청주지사']
# 누적거리 :    1039.4229310918474 / 누적시간  :         130.30369137414564 / Rest_time :    274.6963086258544 / possible stock :, nan   / possible time :         109.99105816401813
# From : 남청주지사 To : 청주지사
# 누적거리 :    1126.6549518867562 / 누적시간  :         234.98211632803626 / Rest_time :    170.01788367196377  / possible stock :, nan >> 복귀 완료
#
#
#
# VVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVV 1126.6549518867562
# From : 남청주지사 To : DP
# Point_list :  ['DP']
# @@@@@@@@@@@@@@@@@@@@@@@@               check the stopby : (92, 52)
# ---------------------------------------------------------------------------------------------------------------------------------
#
# >> 서김포지사
#  >> currrent_p :  서김포지사 	current_stock :  nan
# dist :	 89.37964412721183 / fast :	 50.0 / time :	 107.2555729526542
# 누적거리 :    1216.034596013968 / 누적시간  :         117.2555729526542 / time :         107.2555729526542 possible stock :	 nan
# Point_list :  ['DP', '서김포지사']
# From : DP To : 서김포지사
# 조건 3 180.48885409469156 nan
# Left  0 count : 91 zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz
# dist :    5.981028822574782 / fast :         50.0 / time :         7.177234587089738
# Point list :  ['DP', '서김포지사', '일산지사']
# 누적거리 :    1222.0156248365427 / 누적시간  :         129.43280753974395 / Rest_time :    275.567192460256 / possible stock :, nan   / possible time :         107.2555729526542
# From : 서김포지사 To : 일산지사
# 누적거리 :    1310.7766437802193 / 누적시간  :         235.94603027215575 / Rest_time :    169.05396972784422  / possible stock :, nan >> 복귀 완료
#
#
#
# VVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVV 1310.7766437802193
# From : 서김포지사 To : DP
# Point_list :  ['DP']
# @@@@@@@@@@@@@@@@@@@@@@@@               check the stopby : (90, 57)
# ---------------------------------------------------------------------------------------------------------------------------------
#
# >> 파주지사
#  >> currrent_p :  파주지사 	current_stock :  nan
# dist :	 86.08896618219175 / fast :	 50.0 / time :	 103.3067594186301
# 누적거리 :    1396.865609962411 / 누적시간  :         113.3067594186301 / time :         103.3067594186301 possible stock :	 nan
# Point_list :  ['DP', '파주지사']
# From : DP To : 파주지사
# 조건 3 188.38648116273978 nan
# Left  0 count : 89 zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz
# dist :    5.202363403978673 / fast :         50.0 / time :         6.2428360847744075
# Point list :  ['DP', '파주지사', '파주운정지사']
# 누적거리 :    1402.0679733663899 / 누적시간  :         124.5495955034045 / Rest_time :    280.45040449659547 / possible stock :, nan   / possible time :         103.3067594186301
# From : 파주지사 To : 파주운정지사
# 누적거리 :    1484.354611041241 / 누적시간  :         223.29356071322593 / Rest_time :    181.70643928677404  / possible stock :, nan >> 복귀 완료
#
#
#
# VVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVV 1484.354611041241
# From : 파주지사 To : DP
# Point_list :  ['DP']
# @@@@@@@@@@@@@@@@@@@@@@@@               check the stopby : (88, 62)
# ---------------------------------------------------------------------------------------------------------------------------------
#
# >> 일산동구지사
#  >> currrent_p :  일산동구지사 	current_stock :  nan
# dist :	 82.40481088292006 / fast :	 50.0 / time :	 98.88577305950407
# 누적거리 :    1566.759421924161 / 누적시간  :         108.88577305950407 / time :         98.88577305950407 possible stock :	 nan
# Point_list :  ['DP', '일산동구지사']
# From : DP To : 일산동구지사
# 조건 3 197.22845388099188 nan
# Left  0 count : 87 zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz
# dist :    6.348936906826292 / fast :         50.0 / time :         7.618724288191551
# Point list :  ['DP', '일산동구지사', '김포지사']
# 누적거리 :    1573.1083588309873 / 누적시간  :         121.50449734769563 / Rest_time :    283.49550265230437 / possible stock :, nan   / possible time :         98.88577305950407
# From : 일산동구지사 To : 김포지사
# 누적거리 :    1651.5963716814142 / 누적시간  :         215.69011276820788 / Rest_time :    189.30988723179212  / possible stock :, nan >> 복귀 완료
#
#
#
# VVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVV 1651.5963716814142
# From : 일산동구지사 To : DP
# Point_list :  ['DP']
# @@@@@@@@@@@@@@@@@@@@@@@@               check the stopby : (86, 67)
# ---------------------------------------------------------------------------------------------------------------------------------
#
# >> 탄현지사
#  >> currrent_p :  탄현지사 	current_stock :  nan
# dist :	 79.32140941638865 / fast :	 50.0 / time :	 95.18569129966637
# 누적거리 :    1730.9177810978028 / 누적시간  :         105.18569129966637 / time :         95.18569129966637 possible stock :	 nan
# Point_list :  ['DP', '탄현지사']
# From : DP To : 탄현지사
# 조건 3 204.62861740066728 nan
# Left  0 count : 85 zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz
# dist :    5.6006114056576575 / fast :         50.0 / time :         6.720733686789188
# Point list :  ['DP', '탄현지사', '고양지사']
# 누적거리 :    1736.5183925034605 / 누적시간  :         116.90642498645556 / Rest_time :    288.09357501354447 / possible stock :, nan   / possible time :         95.18569129966637
# From : 탄현지사 To : 고양지사
# 누적거리 :    1810.2391905141915 / 누적시간  :         205.37138259933275 / Rest_time :    199.62861740066728  / possible stock :, nan >> 복귀 완료
#
#
#
# VVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVV 1810.2391905141915
# From : 탄현지사 To : DP
# Point_list :  ['DP']
# @@@@@@@@@@@@@@@@@@@@@@@@               check the stopby : (84, 72)
# ---------------------------------------------------------------------------------------------------------------------------------
#
# >> 서인천지사
#  >> currrent_p :  서인천지사 	current_stock :  nan
# dist :	 78.96271628957719 / fast :	 50.0 / time :	 94.75525954749261
# 누적거리 :    1889.2019068037687 / 누적시간  :         104.75525954749261 / time :         94.75525954749261 possible stock :	 nan
# Point_list :  ['DP', '서인천지사']
# From : DP To : 서인천지사
# 조건 3 205.48948090501474 nan
# Left  0 count : 83 zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz
# dist :    9.141585720669863 / fast :         50.0 / time :         10.969902864803835
# Point list :  ['DP', '서인천지사', '동인천지사']
# 누적거리 :    1898.3434925244385 / 누적시간  :         120.72516241229644 / Rest_time :    284.27483758770353 / possible stock :, nan   / possible time :         94.75525954749261
# From : 서인천지사 To : 동인천지사
# 누적거리 :    1969.4815633103221 / 누적시간  :         206.09084735535694 / Rest_time :    198.90915264464303  / possible stock :, nan >> 복귀 완료
#
#
#
# VVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVV 1969.4815633103221
# From : 서인천지사 To : DP
# Point_list :  ['DP']
# @@@@@@@@@@@@@@@@@@@@@@@@               check the stopby : (82, 77)
# ---------------------------------------------------------------------------------------------------------------------------------
#
# >> 세종지사
#  >> currrent_p :  세종지사 	current_stock :  nan
# dist :	 75.21415241743632 / fast :	 50.0 / time :	 90.25698290092359
# 누적거리 :    2044.6957157277584 / 누적시간  :         100.25698290092359 / time :         90.25698290092359 possible stock :	 nan
# Point_list :  ['DP', '세종지사']
# From : DP To : 세종지사
# 조건 3 214.4860341981528 nan
# Left  0 count : 81 zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz
# dist :    30.80391346753622 / fast :         50.0 / time :         36.96469616104346
# Point list :  ['DP', '세종지사', '공주지사']
# 누적거리 :    2075.499629195295 / 누적시간  :         142.22167906196705 / Rest_time :    262.77832093803295 / possible stock :, nan   / possible time :         90.25698290092359
# From : 세종지사 To : 공주지사
# 누적거리 :    2139.06077544398 / 누적시간  :         218.49505456038946 / Rest_time :    186.50494543961054  / possible stock :, nan >> 복귀 완료
#
#
#
# VVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVV 2139.06077544398
# From : 세종지사 To : DP
# Point_list :  ['DP']
# @@@@@@@@@@@@@@@@@@@@@@@@               check the stopby : (80, 82)
# ---------------------------------------------------------------------------------------------------------------------------------
#
# >> 당진지사
#  >> currrent_p :  당진지사 	current_stock :  nan
# dist :	 74.02292039754781 / fast :	 50.0 / time :	 88.82750447705737
# 누적거리 :    2213.083695841528 / 누적시간  :         98.82750447705737 / time :         88.82750447705737 possible stock :	 nan
# Point_list :  ['DP', '당진지사']
# From : DP To : 당진지사
# 조건 3 217.34499104588528 nan
# Left  0 count : 79 zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz
# dist :    51.949989700629196 / fast :         50.0 / time :         62.339987640755034
# Point list :  ['DP', '당진지사', '시흥정왕지사']
# 누적거리 :    2265.033685542157 / 누적시간  :         166.1674921178124 / Rest_time :    238.83250788218763 / possible stock :, nan   / possible time :         88.82750447705737
# From : 당진지사 To : 시흥정왕지사
# 누적거리 :    2318.787164052274 / 누적시간  :         230.67166632995264 / Rest_time :    174.32833367004736  / possible stock :, nan >> 복귀 완료
#
#
#
# VVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVV 2318.787164052274
# From : 당진지사 To : DP
# Point_list :  ['DP']
# @@@@@@@@@@@@@@@@@@@@@@@@               check the stopby : (78, 87)
# ---------------------------------------------------------------------------------------------------------------------------------
#
# >> 가양지사
#  >> currrent_p :  가양지사 	current_stock :  nan
# dist :	 69.29307041715109 / fast :	 50.0 / time :	 83.1516845005813
# 누적거리 :    2388.0802344694252 / 누적시간  :         93.1516845005813 / time :         83.1516845005813 possible stock :	 nan
# Point_list :  ['DP', '가양지사']
# From : DP To : 가양지사
# 조건 3 228.69663099883743 nan
# Left  0 count : 77 zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz
# dist :    5.582644262900797 / fast :         50.0 / time :         6.699173115480957
# Point list :  ['DP', '가양지사', '부천상동지사']
# 누적거리 :    2393.662878732326 / 누적시간  :         104.85085761606226 / Rest_time :    300.1491423839378 / possible stock :, nan   / possible time :         83.1516845005813
# From : 가양지사 To : 부천상동지사
# 누적거리 :    2457.3733048865765 / 누적시간  :         181.3033690011626 / Rest_time :    223.6966309988374  / possible stock :, nan >> 복귀 완료
#
#
#
# VVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVV 2457.3733048865765
# From : 가양지사 To : DP
# Point_list :  ['DP']
# @@@@@@@@@@@@@@@@@@@@@@@@               check the stopby : (76, 92)
# ---------------------------------------------------------------------------------------------------------------------------------
#
# >> 부평지사
#  >> currrent_p :  부평지사 	current_stock :  nan
# dist :	 66.5257725729578 / fast :	 50.0 / time :	 79.83092708754937
# 누적거리 :    2523.8990774595345 / 누적시간  :         89.83092708754937 / time :         79.83092708754937 possible stock :	 nan
# Point_list :  ['DP', '부평지사']
# From : DP To : 부평지사
# 조건 3 235.3381458249013 nan
# Left  0 count : 75 zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz
# dist :    5.978304692893615 / fast :         50.0 / time :         7.173965631472338
# Point list :  ['DP', '부평지사', '남인천지사']
# 누적거리 :    2529.8773821524283 / 누적시간  :         102.00489271902171 / Rest_time :    302.9951072809783 / possible stock :, nan   / possible time :         79.83092708754937
# From : 부평지사 To : 남인천지사
# 누적거리 :    2590.609171956285 / 누적시간  :         174.88304048364995 / Rest_time :    230.11695951635005  / possible stock :, nan >> 복귀 완료
#
#
#
# VVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVV 2590.609171956285
# From : 부평지사 To : DP
# Point_list :  ['DP']
# @@@@@@@@@@@@@@@@@@@@@@@@               check the stopby : (74, 97)
# ---------------------------------------------------------------------------------------------------------------------------------
#
# >> 양주지사
#  >> currrent_p :  양주지사 	current_stock :  nan
# dist :	 65.79403449186849 / fast :	 50.0 / time :	 78.95284139024218
# 누적거리 :    2656.4032064481535 / 누적시간  :         88.95284139024218 / time :         78.95284139024218 possible stock :	 nan
# Point_list :  ['DP', '양주지사']
# From : DP To : 양주지사
# 조건 3 237.09431721951566 nan
# Left  0 count : 73 zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz
# dist :    14.962488011927366 / fast :         50.0 / time :         17.95498561431284
# Point list :  ['DP', '양주지사', '의정부지사']
# 누적거리 :    2671.3656944600807 / 누적시간  :         111.90782700455503 / Rest_time :    293.092172995445 / possible stock :, nan   / possible time :         78.95284139024218
# From : 양주지사 To : 의정부지사
# 누적거리 :    2726.8652446778774 / 누적시간  :         178.50728726591097 / Rest_time :    226.49271273408908  / possible stock :, nan >> 복귀 완료
#
#
#
# VVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVV 2726.8652446778774
# From : 양주지사 To : DP
# Point_list :  ['DP']
# @@@@@@@@@@@@@@@@@@@@@@@@               check the stopby : (72, 102)
# ---------------------------------------------------------------------------------------------------------------------------------
#
# >> 부천오정지사
#  >> currrent_p :  부천오정지사 	current_stock :  nan
# dist :	 63.51473559225653 / fast :	 50.0 / time :	 76.21768271070783
# 누적거리 :    2790.3799802701337 / 누적시간  :         86.21768271070783 / time :         76.21768271070783 possible stock :	 nan
# Point_list :  ['DP', '부천오정지사']
# From : DP To : 부천오정지사
# 조건 3 242.56463457858433 nan
# Left  0 count : 71 zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz
# dist :    1.7868941670246568 / fast :         50.0 / time :         2.144273000429588
# Point list :  ['DP', '부천오정지사', '부천지사']
# 누적거리 :    2792.166874437158 / 누적시간  :         93.36195571113743 / Rest_time :    311.6380442888626 / possible stock :, nan   / possible time :         76.21768271070783
# From : 부천오정지사 To : 부천지사
# 누적거리 :    2854.4201723009896 / 누적시간  :         168.0659131477351 / Rest_time :    236.93408685226495  / possible stock :, nan >> 복귀 완료
#
#
#
# VVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVV 2854.4201723009896
# From : 부천오정지사 To : DP
# Point_list :  ['DP']
# @@@@@@@@@@@@@@@@@@@@@@@@               check the stopby : (70, 107)
# ---------------------------------------------------------------------------------------------------------------------------------
#
# >> 양천지사
#  >> currrent_p :  양천지사 	current_stock :  nan
# dist :	 61.49410354971312 / fast :	 50.0 / time :	 73.79292425965575
# 누적거리 :    2915.914275850703 / 누적시간  :         83.79292425965575 / time :         73.79292425965575 possible stock :	 nan
# Point_list :  ['DP', '양천지사']
# From : DP To : 양천지사
# 조건 3 247.41415148068847 nan
# Left  0 count : 69 zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz
# dist :    8.55762581228575 / fast :         50.0 / time :         10.2691509747429
# Point list :  ['DP', '양천지사', '구로지사']
# 누적거리 :    2924.4719016629883 / 누적시간  :         99.06207523439865 / Rest_time :    305.93792476560134 / possible stock :, nan   / possible time :         73.79292425965575
# From : 양천지사 To : 구로지사
# 누적거리 :    2977.4083794004155 / 누적시간  :         162.58584851931147 / Rest_time :    242.4141514806885  / possible stock :, nan >> 복귀 완료
#
#
#
# VVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVV 2977.4083794004155
# From : 양천지사 To : DP
# Point_list :  ['DP']
# @@@@@@@@@@@@@@@@@@@@@@@@               check the stopby : (68, 112)
# ---------------------------------------------------------------------------------------------------------------------------------
#
# >> 수색지사
#  >> currrent_p :  수색지사 	current_stock :  nan
# dist :	 60.41633972618084 / fast :	 50.0 / time :	 72.499607671417
# 누적거리 :    3037.8247191265964 / 누적시간  :         82.499607671417 / time :         72.499607671417 possible stock :	 nan
# Point_list :  ['DP', '수색지사']
# From : DP To : 수색지사
# 조건 3 250.00078465716604 nan
# Left  0 count : 67 zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz
# dist :    4.588606538063698 / fast :         50.0 / time :         5.506327845676437
# Point list :  ['DP', '수색지사', '은평지사']
# 누적거리 :    3042.41332566466 / 누적시간  :         93.00593551709343 / Rest_time :    311.9940644829066 / possible stock :, nan   / possible time :         72.499607671417
# From : 수색지사 To : 은평지사
# 누적거리 :    3098.5037852378173 / 누적시간  :         160.31448700488227 / Rest_time :    244.68551299511773  / possible stock :, nan >> 복귀 완료
#
#
#
# VVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVV 3098.5037852378173
# From : 수색지사 To : DP
# Point_list :  ['DP']
# @@@@@@@@@@@@@@@@@@@@@@@@               check the stopby : (66, 117)
# ---------------------------------------------------------------------------------------------------------------------------------
#
# >> 인천지사
#  >> currrent_p :  인천지사 	current_stock :  nan
# dist :	 60.08826982718143 / fast :	 50.0 / time :	 72.10592379261772
# 누적거리 :    3158.592055064999 / 누적시간  :         82.10592379261772 / time :         72.10592379261772 possible stock :	 nan
# Point_list :  ['DP', '인천지사']
# From : DP To : 인천지사
# 조건 3 250.78815241476457 nan
# Left  0 count : 65 zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz
# dist :    14.325036302829123 / fast :         50.0 / time :         17.190043563394948
# Point list :  ['DP', '인천지사', '시흥지사']
# 누적거리 :    3172.917091367828 / 누적시간  :         104.29596735601267 / Rest_time :    300.7040326439873 / possible stock :, nan   / possible time :         72.10592379261772
# From : 인천지사 To : 시흥지사
# 누적거리 :    3218.6803248921806 / 누적시간  :         159.21184758523543 / Rest_time :    245.78815241476454  / possible stock :, nan >> 복귀 완료
#
#
#
# VVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVV 3218.6803248921806
# From : 인천지사 To : DP
# Point_list :  ['DP']
# @@@@@@@@@@@@@@@@@@@@@@@@               check the stopby : (64, 122)
# ---------------------------------------------------------------------------------------------------------------------------------
#
# >> 등촌지사
#  >> currrent_p :  등촌지사 	current_stock :  nan
# dist :	 58.46047733392399 / fast :	 50.0 / time :	 70.15257280070878
# 누적거리 :    3277.1408022261044 / 누적시간  :         80.15257280070878 / time :         70.15257280070878 possible stock :	 nan
# Point_list :  ['DP', '등촌지사']
# From : DP To : 등촌지사
# 조건 3 254.69485439858246 nan
# Left  0 count : 63 zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz
# dist :    2.46993881381941 / fast :         50.0 / time :         2.963926576583292
# Point list :  ['DP', '등촌지사', '강서지사']
# 누적거리 :    3279.6107410399236 / 누적시간  :         88.11649937729207 / Rest_time :    316.88350062270797 / possible stock :, nan   / possible time :         70.15257280070878
# From : 등촌지사 To : 강서지사
# 누적거리 :    3335.601279560028 / 누적시간  :         155.30514560141756 / Rest_time :    249.69485439858246  / possible stock :, nan >> 복귀 완료
#
#
#
# VVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVV 3335.601279560028
# From : 등촌지사 To : DP
# Point_list :  ['DP']
# @@@@@@@@@@@@@@@@@@@@@@@@               check the stopby : (62, 127)
# ---------------------------------------------------------------------------------------------------------------------------------
#
# >> 서대문지사
#  >> currrent_p :  서대문지사 	current_stock :  nan
# dist :	 54.139898579311534 / fast :	 50.0 / time :	 64.96787829517383
# 누적거리 :    3389.74117813934 / 누적시간  :         74.96787829517383 / time :         64.96787829517383 possible stock :	 nan
# Point_list :  ['DP', '서대문지사']
# From : DP To : 서대문지사
# 조건 3 265.06424340965236 nan
# Left  0 count : 61 zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz
# dist :    2.001771451187387 / fast :         50.0 / time :         2.4021257414248645
# Point list :  ['DP', '서대문지사', '마포성산지사']
# 누적거리 :    3391.742949590527 / 누적시간  :         82.3700040365987 / Rest_time :    322.6299959634013 / possible stock :, nan   / possible time :         64.96787829517383
# From : 서대문지사 To : 마포성산지사
# 누적거리 :    3445.526771896347 / 누적시간  :         146.91059080358258 / Rest_time :    258.0894091964174  / possible stock :, nan >> 복귀 완료
#
#
#
# VVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVV 3445.526771896347
# From : 서대문지사 To : DP
# Point_list :  ['DP']
# @@@@@@@@@@@@@@@@@@@@@@@@               check the stopby : (60, 132)
# ---------------------------------------------------------------------------------------------------------------------------------
#
# >> 덕소지사
#  >> currrent_p :  덕소지사 	current_stock :  nan
# dist :	 52.063089163767 / fast :	 50.0 / time :	 62.47570699652041
# 누적거리 :    3497.589861060114 / 누적시간  :         72.47570699652042 / time :         62.47570699652041 possible stock :	 nan
# Point_list :  ['DP', '덕소지사']
# From : DP To : 덕소지사
# 조건 3 270.0485860069592 nan
# Left  0 count : 59 zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz
# dist :    3.7213180552826963 / fast :         50.0 / time :         4.465581666339236
# Point list :  ['DP', '덕소지사', '하남지사']
# 누적거리 :    3501.3111791153965 / 누적시간  :         81.94128866285965 / Rest_time :    323.0587113371404 / possible stock :, nan   / possible time :         62.47570699652041
# From : 덕소지사 To : 하남지사
# 누적거리 :    3549.652950223881 / 누적시간  :         139.95141399304083 / Rest_time :    265.0485860069592  / possible stock :, nan >> 복귀 완료
#
#
#
# VVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVV 3549.652950223881
# From : 덕소지사 To : DP
# Point_list :  ['DP']
# @@@@@@@@@@@@@@@@@@@@@@@@               check the stopby : (58, 137)
# ---------------------------------------------------------------------------------------------------------------------------------
#
# >> 영등포양평지사
#  >> currrent_p :  영등포양평지사 	current_stock :  nan
# dist :	 50.344544024342305 / fast :	 50.0 / time :	 60.41345282921077
# 누적거리 :    3599.997494248223 / 누적시간  :         70.41345282921077 / time :         60.41345282921077 possible stock :	 nan
# Point_list :  ['DP', '영등포양평지사']
# From : DP To : 영등포양평지사
# 조건 3 274.17309434157846 nan
# Left  0 count : 57 zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz
# dist :    2.657345961515745 / fast :         50.0 / time :         3.188815153818894
# Point list :  ['DP', '영등포양평지사', '영등포지사']
# 누적거리 :    3602.6548402097387 / 누적시간  :         78.60226798302966 / Rest_time :    326.39773201697034 / possible stock :, nan   / possible time :         60.41345282921077
# From : 영등포양평지사 To : 영등포지사
# 누적거리 :    3650.8073861610837 / 누적시간  :         136.38532312464343 / Rest_time :    268.61467687535657  / possible stock :, nan >> 복귀 완료
#
#
#
# VVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVV 3650.8073861610837
# From : 영등포양평지사 To : DP
# Point_list :  ['DP']
# @@@@@@@@@@@@@@@@@@@@@@@@               check the stopby : (56, 142)
# ---------------------------------------------------------------------------------------------------------------------------------
#
# >> 의정부용현지사
#  >> currrent_p :  의정부용현지사 	current_stock :  nan
# dist :	 50.10502422102309 / fast :	 50.0 / time :	 60.12602906522772
# 누적거리 :    3700.912410382107 / 누적시간  :         70.12602906522773 / time :         60.12602906522772 possible stock :	 nan
# Point_list :  ['DP', '의정부용현지사']
# From : DP To : 의정부용현지사
# 조건 3 274.74794186954455 nan
# Left  0 count : 55 zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz
# dist :    8.09677402452104 / fast :         50.0 / time :         9.716128829425246
# Point list :  ['DP', '의정부용현지사', '상계지사']
# 누적거리 :    3709.009184406628 / 누적시간  :         84.84215789465297 / Rest_time :    320.157842105347 / possible stock :, nan   / possible time :         60.12602906522772
# From : 의정부용현지사 To : 상계지사
# 누적거리 :    3756.535808461764 / 누적시간  :         141.87410676081637 / Rest_time :    263.1258932391836  / possible stock :, nan >> 복귀 완료
#
#
#
# VVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVV 3756.535808461764
# From : 의정부용현지사 To : DP
# Point_list :  ['DP']
# @@@@@@@@@@@@@@@@@@@@@@@@               check the stopby : (54, 147)
# ---------------------------------------------------------------------------------------------------------------------------------
#
# >> 수유지사
#  >> currrent_p :  수유지사 	current_stock :  nan
# dist :	 47.528490691100316 / fast :	 50.0 / time :	 57.03418882932038
# 누적거리 :    3804.0642991528644 / 누적시간  :         67.03418882932039 / time :         57.03418882932038 possible stock :	 nan
# Point_list :  ['DP', '수유지사']
# From : DP To : 수유지사
# 조건 3 280.93162234135923 nan
# Left  0 count : 53 zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz
# dist :    2.233775954770649 / fast :         50.0 / time :         2.6805311457247787
# Point list :  ['DP', '수유지사', '도봉지사']
# 누적거리 :    3806.298075107635 / 누적시간  :         74.71471997504517 / Rest_time :    330.28528002495483 / possible stock :, nan   / possible time :         57.03418882932038
# From : 수유지사 To : 도봉지사
# 누적거리 :    3852.7655737603227 / 누적시간  :         130.4757183582703 / Rest_time :    274.5242816417297  / possible stock :, nan >> 복귀 완료
#
#
#
# VVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVV 3852.7655737603227
# From : 수유지사 To : DP
# Point_list :  ['DP']
# @@@@@@@@@@@@@@@@@@@@@@@@               check the stopby : (52, 152)
# ---------------------------------------------------------------------------------------------------------------------------------
#
# >> 남구로지사
#  >> currrent_p :  남구로지사 	current_stock :  nan
# dist :	 47.286042850099335 / fast :	 50.0 / time :	 56.7432514201192
# 누적거리 :    3900.051616610422 / 누적시간  :         66.74325142011921 / time :         56.7432514201192 possible stock :	 nan
# Point_list :  ['DP', '남구로지사']
# From : DP To : 남구로지사
# 조건 3 281.51349715976164 nan
# Left  0 count : 51 zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz
# dist :    1.174867160581163 / fast :         50.0 / time :         1.4098405926973954
# Point list :  ['DP', '남구로지사', '관악지사']
# 누적거리 :    3901.226483771003 / 누적시간  :         73.1530920128166 / Rest_time :    331.84690798718344 / possible stock :, nan   / possible time :         56.7432514201192
# From : 남구로지사 To : 관악지사
# 누적거리 :    3948.0981019822025 / 누적시간  :         129.39903386625576 / Rest_time :    275.6009661337443  / possible stock :, nan >> 복귀 완료
#
#
#
# VVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVV 3948.0981019822025
# From : 남구로지사 To : DP
# Point_list :  ['DP']
# @@@@@@@@@@@@@@@@@@@@@@@@               check the stopby : (50, 157)
# ---------------------------------------------------------------------------------------------------------------------------------
#
# >> 독산지사
#  >> currrent_p :  독산지사 	current_stock :  nan
# dist :	 46.71591828197687 / fast :	 50.0 / time :	 56.059101938372244
# 누적거리 :    3994.8140202641794 / 누적시간  :         66.05910193837224 / time :         56.059101938372244 possible stock :	 nan
# Point_list :  ['DP', '독산지사']
# From : DP To : 독산지사
# 조건 3 282.8817961232555 nan
# Left  0 count : 49 zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz
# dist :    9.53850386473354 / fast :         50.0 / time :         11.446204637680248
# Point list :  ['DP', '독산지사', '동작지사']
# 누적거리 :    4004.352524128913 / 누적시간  :         82.50530657605249 / Rest_time :    322.4946934239475 / possible stock :, nan   / possible time :         56.059101938372244
# From : 독산지사 To : 동작지사
# 누적거리 :    4047.9919018970763 / 누적시간  :         134.8725598978484 / Rest_time :    270.12744010215164  / possible stock :, nan >> 복귀 완료
#
#
#
# VVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVV 4047.9919018970763
# From : 독산지사 To : DP
# Point_list :  ['DP']
# @@@@@@@@@@@@@@@@@@@@@@@@               check the stopby : (48, 162)
# ---------------------------------------------------------------------------------------------------------------------------------
#
# >> 성북지사
#  >> currrent_p :  성북지사 	current_stock :  nan
# dist :	 46.002476427680875 / fast :	 50.0 / time :	 55.20297171321705
# 누적거리 :    4093.9943783247572 / 누적시간  :         65.20297171321705 / time :         55.20297171321705 possible stock :	 nan
# Point_list :  ['DP', '성북지사']
# From : DP To : 성북지사
# 조건 3 284.5940565735659 nan
# Left  0 count : 47 zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz
# dist :    5.006320366499869 / fast :         50.0 / time :         6.007584439799843
# Point list :  ['DP', '성북지사', '동대문지사']
# 누적거리 :    4099.000698691257 / 누적시간  :         76.2105561530169 / Rest_time :    328.7894438469831 / possible stock :, nan   / possible time :         55.20297171321705
# From : 성북지사 To : 동대문지사
# 누적거리 :    4139.996854752438 / 누적시간  :         125.4059434264341 / Rest_time :    279.59405657356587  / possible stock :, nan >> 복귀 완료
#
#
#
# VVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVV 4139.996854752438
# From : 성북지사 To : DP
# Point_list :  ['DP']
# @@@@@@@@@@@@@@@@@@@@@@@@               check the stopby : (46, 167)
# ---------------------------------------------------------------------------------------------------------------------------------
#
# >> 구리지사
#  >> currrent_p :  구리지사 	current_stock :  nan
# dist :	 45.45735001656219 / fast :	 50.0 / time :	 54.548820019874626
# 누적거리 :    4185.454204769 / 누적시간  :         64.54882001987463 / time :         54.548820019874626 possible stock :	 nan
# Point_list :  ['DP', '구리지사']
# From : DP To : 구리지사
# 조건 3 285.9023599602508 nan
# Left  0 count : 45 zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz
# dist :    4.887457587826089 / fast :         50.0 / time :         5.864949105391306
# Point list :  ['DP', '구리지사', '구의지사']
# 누적거리 :    4190.341662356826 / 누적시간  :         75.41376912526593 / Rest_time :    329.5862308747341 / possible stock :, nan   / possible time :         54.548820019874626
# From : 구리지사 To : 구의지사
# 누적거리 :    4230.911554785563 / 누적시간  :         124.09764003974925 / Rest_time :    280.9023599602508  / possible stock :, nan >> 복귀 완료
#
#
#
# VVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVV 4230.911554785563
# From : 구리지사 To : DP
# Point_list :  ['DP']
# @@@@@@@@@@@@@@@@@@@@@@@@               check the stopby : (44, 172)
# ---------------------------------------------------------------------------------------------------------------------------------
#
# >> 천안지사
#  >> currrent_p :  천안지사 	current_stock :  nan
# dist :	 41.27217264919571 / fast :	 50.0 / time :	 49.526607179034855
# 누적거리 :    4272.183727434758 / 누적시간  :         59.526607179034855 / time :         49.526607179034855 possible stock :	 nan
# Point_list :  ['DP', '천안지사']
# From : DP To : 천안지사
# 조건 3 295.9467856419303 nan
# Left  0 count : 43 zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz
# dist :    5.612241411464448 / fast :         50.0 / time :         6.734689693757338
# Point list :  ['DP', '천안지사', '북천안지사']
# 누적거리 :    4277.795968846222 / 누적시간  :         71.26129687279219 / Rest_time :    333.7387031272078 / possible stock :, nan   / possible time :         49.526607179034855
# From : 천안지사 To : 북천안지사
# 누적거리 :    4314.014304932405 / 누적시간  :         114.72330017621135 / Rest_time :    290.27669982378865  / possible stock :, nan >> 복귀 완료
#
#
#
# VVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVV 4314.014304932405
# From : 천안지사 To : DP
# Point_list :  ['DP']
# @@@@@@@@@@@@@@@@@@@@@@@@               check the stopby : (42, 177)
# ---------------------------------------------------------------------------------------------------------------------------------
#
# >> 노원지사
#  >> currrent_p :  노원지사 	current_stock :  nan
# dist :	 40.88032083023659 / fast :	 50.0 / time :	 49.05638499628391
# 누적거리 :    4354.894625762642 / 누적시간  :         59.05638499628391 / time :         49.05638499628391 possible stock :	 nan
# Point_list :  ['DP', '노원지사']
# From : DP To : 노원지사
# 조건 3 296.8872300074322 nan
# Left  0 count : 41 zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz
# dist :    4.084900141031785 / fast :         50.0 / time :         4.901880169238141
# Point list :  ['DP', '노원지사', '중랑지사']
# 누적거리 :    4358.979525903674 / 누적시간  :         68.95826516552205 / Rest_time :    336.04173483447795 / possible stock :, nan   / possible time :         49.05638499628391
# From : 노원지사 To : 중랑지사
# 누적거리 :    4396.086530800709 / 누적시간  :         113.48667104196379 / Rest_time :    291.5133289580362  / possible stock :, nan >> 복귀 완료
#
#
#
# VVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVV 4396.086530800709
# From : 노원지사 To : DP
# Point_list :  ['DP']
# @@@@@@@@@@@@@@@@@@@@@@@@               check the stopby : (40, 182)
# ---------------------------------------------------------------------------------------------------------------------------------
#
# >> 안산지사
#  >> currrent_p :  안산지사 	current_stock :  nan
# dist :	 40.396653318512065 / fast :	 50.0 / time :	 48.47598398221448
# 누적거리 :    4436.483184119221 / 누적시간  :         58.47598398221448 / time :         48.47598398221448 possible stock :	 nan
# Point_list :  ['DP', '안산지사']
# From : DP To : 안산지사
# 조건 3 298.04803203557105 nan
# Left  0 count : 39 zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz
# dist :    6.239238556848379 / fast :         50.0 / time :         7.487086268218055
# Point list :  ['DP', '안산지사', '안산본오지사']
# 누적거리 :    4442.722422676069 / 누적시간  :         70.96307025043254 / Rest_time :    334.0369297495675 / possible stock :, nan   / possible time :         48.47598398221448
# From : 안산지사 To : 안산본오지사
# 누적거리 :    4476.879837437733 / 누적시간  :         111.95196796442897 / Rest_time :    293.04803203557105  / possible stock :, nan >> 복귀 완료
#
#
#
# VVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVV 4476.879837437733
# From : 안산지사 To : DP
# Point_list :  ['DP']
# @@@@@@@@@@@@@@@@@@@@@@@@               check the stopby : (38, 187)
# ---------------------------------------------------------------------------------------------------------------------------------
#
# >> 경안지사
#  >> currrent_p :  경안지사 	current_stock :  nan
# dist :	 38.13959654876875 / fast :	 50.0 / time :	 45.7675158585225
# 누적거리 :    4515.019433986502 / 누적시간  :         55.7675158585225 / time :         45.7675158585225 possible stock :	 nan
# Point_list :  ['DP', '경안지사']
# From : DP To : 경안지사
# 조건 3 303.46496828295494 nan
# Left  0 count : 37 zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz
# dist :    2.3186306570759796 / fast :         50.0 / time :         2.7823567884911755
# Point list :  ['DP', '경안지사', '태전지사']
# 누적거리 :    4517.338064643578 / 누적시간  :         63.54987264701368 / Rest_time :    341.45012735298627 / possible stock :, nan   / possible time :         45.7675158585225
# From : 경안지사 To : 태전지사
# 누적거리 :    4553.2569395030705 / 누적시간  :         106.6525224784049 / Rest_time :    298.34747752159507  / possible stock :, nan >> 복귀 완료
#
#
#
# VVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVV 4553.2569395030705
# From : 경안지사 To : DP
# Point_list :  ['DP']
# @@@@@@@@@@@@@@@@@@@@@@@@               check the stopby : (36, 192)
# ---------------------------------------------------------------------------------------------------------------------------------
#
# >> 강동지사
#  >> currrent_p :  강동지사 	current_stock :  nan
# dist :	 38.078397130959715 / fast :	 50.0 / time :	 45.694076557151654
# 누적거리 :    4591.33533663403 / 누적시간  :         55.694076557151654 / time :         45.694076557151654 possible stock :	 nan
# Point_list :  ['DP', '강동지사']
# From : DP To : 강동지사
# 조건 3 303.61184688569665 nan
# Left  0 count : 35 zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz
# dist :    2.5216885083156635 / fast :         50.0 / time :         3.0260262099787965
# Point list :  ['DP', '강동지사', '송파지사(송파오금지사)']
# 누적거리 :    4593.857025142345 / 누적시간  :         63.72010276713045 / Rest_time :    341.27989723286953 / possible stock :, nan   / possible time :         45.694076557151654
# From : 강동지사 To : 송파지사(송파오금지사)
# 누적거리 :    4630.0739028287435 / 누적시간  :         107.18035599080818 / Rest_time :    297.8196440091918  / possible stock :, nan >> 복귀 완료
#
#
#
# VVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVV 4630.0739028287435
# From : 강동지사 To : DP
# Point_list :  ['DP']
# @@@@@@@@@@@@@@@@@@@@@@@@               check the stopby : (34, 197)
# ---------------------------------------------------------------------------------------------------------------------------------
#
# >> 장안지사
#  >> currrent_p :  장안지사 	current_stock :  nan
# dist :	 36.41350874538882 / fast :	 50.0 / time :	 43.696210494466584
# 누적거리 :    4666.487411574132 / 누적시간  :         53.696210494466584 / time :         43.696210494466584 possible stock :	 nan
# Point_list :  ['DP', '장안지사']
# From : DP To : 장안지사
# 조건 3 307.60757901106683 nan
# Left  0 count : 33 zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz
# dist :    3.51289483563673 / fast :         50.0 / time :         4.215473802764077
# Point list :  ['DP', '장안지사', '광진지사']
# 누적거리 :    4670.000306409769 / 누적시간  :         62.911684297230664 / Rest_time :    342.08831570276936 / possible stock :, nan   / possible time :         43.696210494466584
# From : 장안지사 To : 광진지사
# 누적거리 :    4702.900920319521 / 누적시간  :         102.39242098893317 / Rest_time :    302.60757901106683  / possible stock :, nan >> 복귀 완료
#
#
#
# VVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVV 4702.900920319521
# From : 장안지사 To : DP
# Point_list :  ['DP']
# @@@@@@@@@@@@@@@@@@@@@@@@               check the stopby : (32, 202)
# ---------------------------------------------------------------------------------------------------------------------------------
#
# >> 송파오금지사
#  >> currrent_p :  송파오금지사 	current_stock :  nan
# dist :	 36.20408494398389 / fast :	 50.0 / time :	 43.44490193278067
# 누적거리 :    4739.105005263505 / 누적시간  :         53.44490193278067 / time :         43.44490193278067 possible stock :	 nan
# Point_list :  ['DP', '송파오금지사']
# From : DP To : 송파오금지사
# 조건 3 308.11019613443864 nan
# Left  0 count : 31 zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz
# dist :    3.805998420168832 / fast :         50.0 / time :         4.567198104202598
# Point list :  ['DP', '송파오금지사', '잠실지사']
# 누적거리 :    4742.911003683674 / 누적시간  :         63.01210003698326 / Rest_time :    341.98789996301673 / possible stock :, nan   / possible time :         43.44490193278067
# From : 송파오금지사 To : 잠실지사
# 누적거리 :    4775.309090207489 / 누적시간  :         101.88980386556133 / Rest_time :    303.11019613443864  / possible stock :, nan >> 복귀 완료
#
#
#
# VVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVV 4775.309090207489
# From : 송파오금지사 To : DP
# Point_list :  ['DP']
# @@@@@@@@@@@@@@@@@@@@@@@@               check the stopby : (30, 207)
# ---------------------------------------------------------------------------------------------------------------------------------
#
# >> 아산지사(신규)
#  >> currrent_p :  아산지사(신규) 	current_stock :  nan
# dist :	 36.04404306021194 / fast :	 50.0 / time :	 43.25285167225432
# 누적거리 :    4811.353133267701 / 누적시간  :         53.25285167225432 / time :         43.25285167225432 possible stock :	 nan
# Point_list :  ['DP', '아산지사(신규)']
# From : DP To : 아산지사(신규)
# 조건 3 308.4942966554913 nan
# Left  0 count : 29 zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz
# dist :    20.131417706940297 / fast :         50.0 / time :         24.157701248328355
# Point list :  ['DP', '아산지사(신규)', '평택지사']
# 누적거리 :    4831.484550974642 / 누적시간  :         82.41055292058267 / Rest_time :    322.5894470794173 / possible stock :, nan   / possible time :         43.25285167225432
# From : 아산지사(신규) To : 평택지사
# 누적거리 :    4847.397176327913 / 누적시간  :         101.50570334450865 / Rest_time :    303.4942966554913  / possible stock :, nan >> 복귀 완료
#
#
#
# VVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVV 4847.397176327913
# From : 아산지사(신규) To : DP
# Point_list :  ['DP']
# @@@@@@@@@@@@@@@@@@@@@@@@               check the stopby : (28, 212)
# ---------------------------------------------------------------------------------------------------------------------------------
#
# ...
# From : 여수지사 To : DP
# Point_list :  ['DP']
# @@@@@@@@@@@@@@@@@@@@@@@@               check the stopby : (23, 47)
# ---------------------------------------------------------------------------------------------------------------------------------
#
# >> 포항북구지사
#  >> currrent_p :  포항북구지사 	current_stock :  nan
# dist :	 129.54219143814328 / fast :	 50.0 / time :	 155.45062972577193
# 누적거리 :    2302.0066554313285 / 누적시간  :         165.45062972577193 / time :         155.45062972577193 possible stock :	 nan
# Point_list :  ['DP', '포항북구지사']
# From : DP To : 포항북구지사
# 조건 3 84.09874054845614 nan
# Left  0 count : 22 zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz
# dist :    16.684971185158346 / fast :         50.0 / time :         20.021965422190014
# Point list :  ['DP', '포항북구지사', '포항지사']
# 누적거리 :    2318.6916266164867 / 누적시간  :         190.47259514796195 / Rest_time :    214.52740485203805 / possible stock :, nan   / possible time :         155.45062972577193
# From : 포항북구지사 To : 포항지사
# 누적거리 :    2431.5488468694716 / 누적시간  :         325.90125945154386 / Rest_time :    79.0987405484561  / possible stock :, nan >> 복귀 완료
#
#
#
# VVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVV 2431.5488468694716
# From : 포항북구지사 To : DP
# Point_list :  ['DP']
# @@@@@@@@@@@@@@@@@@@@@@@@               check the stopby : (21, 52)
# ---------------------------------------------------------------------------------------------------------------------------------
#
# >> 구미지사
#  >> currrent_p :  구미지사 	current_stock :  nan
# dist :	 128.8777727064912 / fast :	 50.0 / time :	 154.65332724778946
# 누적거리 :    2560.426619575963 / 누적시간  :         164.65332724778946 / time :         154.65332724778946 possible stock :	 nan
# Point_list :  ['DP', '구미지사']
# From : DP To : 구미지사
# 조건 3 85.69334550442107 nan
# Left  0 count : 20 zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz
# dist :    28.621668481414815 / fast :         50.0 / time :         34.34600217769778
# Point list :  ['DP', '구미지사', '서대구지사']
# 누적거리 :    2589.0482880573777 / 누적시간  :         203.99932942548725 / Rest_time :    201.00067057451275 / possible stock :, nan   / possible time :         154.65332724778946
# From : 구미지사 To : 서대구지사
# 누적거리 :    2689.304392282454 / 누적시간  :         324.3066544955789 / Rest_time :    80.69334550442107  / possible stock :, nan >> 복귀 완료
#
#
#
# VVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVV 2689.304392282454
# From : 구미지사 To : DP
# Point_list :  ['DP']
# @@@@@@@@@@@@@@@@@@@@@@@@               check the stopby : (19, 57)
# ---------------------------------------------------------------------------------------------------------------------------------
#
# >> 안동지사
#  >> currrent_p :  안동지사 	current_stock :  nan
# dist :	 128.07745831914556 / fast :	 50.0 / time :	 153.69294998297468
# 누적거리 :    2817.3818506015996 / 누적시간  :         163.69294998297468 / time :         153.69294998297468 possible stock :	 nan
# Point_list :  ['DP', '안동지사']
# From : DP To : 안동지사
# 조건 3 87.61410003405064 nan
# Left  0 count : 18 zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz
# dist :    68.46673468928599 / fast :         50.0 / time :         82.16008162714319
# Point list :  ['DP', '안동지사', '대구신평지사 ']
# 누적거리 :    2885.8485852908857 / 누적시간  :         250.85303161011785 / Rest_time :    154.14696838988215 / possible stock :, nan   / possible time :         153.69294998297468
# From : 안동지사 To : 대구신평지사
# 누적거리 :    2966.4017164488773 / 누적시간  :         347.5167889997076 / Rest_time :    57.483211000292414  / possible stock :, nan >> 복귀 완료
#
#
#
# VVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVV 2966.4017164488773
# From : 안동지사 To : DP
# Point_list :  ['DP']
# @@@@@@@@@@@@@@@@@@@@@@@@               check the stopby : (17, 62)
# ---------------------------------------------------------------------------------------------------------------------------------
#
# >> 북대구지사
#  >> currrent_p :  북대구지사 	current_stock :  nan
# dist :	 98.97179261327477 / fast :	 50.0 / time :	 118.76615113592972
# 누적거리 :    3065.373509062152 / 누적시간  :         128.7661511359297 / time :         118.76615113592972 possible stock :	 nan
# Point_list :  ['DP', '북대구지사']
# From : DP To : 북대구지사
# 조건 3 157.4676977281406 nan
# Left  0 count : 16 zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz
# dist :    9.016345791466563 / fast :         50.0 / time :         10.819614949759874
# Point list :  ['DP', '북대구지사', '남대구지사']
# 누적거리 :    3074.3898548536185 / 누적시간  :         144.58576608568958 / Rest_time :    260.41423391431044 / possible stock :, nan   / possible time :         118.76615113592972
# From : 북대구지사 To : 남대구지사
# 누적거리 :    3164.3453016754265 / 누적시간  :         252.53230227185944 / Rest_time :    152.4676977281406  / possible stock :, nan >> 복귀 완료
#
#
#
# VVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVV 3164.3453016754265
# From : 북대구지사 To : DP
# Point_list :  ['DP']
# @@@@@@@@@@@@@@@@@@@@@@@@               check the stopby : (15, 67)
# ---------------------------------------------------------------------------------------------------------------------------------
#
# >> 통영지사
#  >> currrent_p :  통영지사 	current_stock :  nan
# dist :	 85.69937261400835 / fast :	 50.0 / time :	 102.83924713681002
# 누적거리 :    3250.044674289435 / 누적시간  :         112.83924713681002 / time :         102.83924713681002 possible stock :	 nan
# Point_list :  ['DP', '통영지사']
# From : DP To : 통영지사
# 조건 3 189.32150572638 nan
# Left  0 count : 14 zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz
# dist :    46.874073108671226 / fast :         50.0 / time :         56.24888773040547
# Point list :  ['DP', '통영지사', '창원지사']
# 누적거리 :    3296.9187473981065 / 누적시간  :         174.0881348672155 / Rest_time :    230.91186513278453 / possible stock :, nan   / possible time :         102.83924713681002
# From : 통영지사 To : 창원지사
# 누적거리 :    3335.7440469034436 / 누적시간  :         220.67849427362006 / Rest_time :    184.32150572637997  / possible stock :, nan >> 복귀 완료
#
#
#
# VVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVV 3335.7440469034436
# From : 통영지사 To : DP
# Point_list :  ['DP']
# @@@@@@@@@@@@@@@@@@@@@@@@               check the stopby : (13, 72)
# ---------------------------------------------------------------------------------------------------------------------------------
#
# >> 동대구지사
#  >> currrent_p :  동대구지사 	current_stock :  nan
# dist :	 84.27771946626578 / fast :	 50.0 / time :	 101.13326335951893
# 누적거리 :    3420.0217663697094 / 누적시간  :         111.13326335951893 / time :         101.13326335951893 possible stock :	 nan
# Point_list :  ['DP', '동대구지사']
# From : DP To : 동대구지사
# 조건 3 192.73347328096213 nan
# Left  0 count : 12 zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz
# dist :    77.8052197354305 / fast :         50.0 / time :         93.3662636825166
# Point list :  ['DP', '동대구지사', '김해지사']
# 누적거리 :    3497.82698610514 / 누적시간  :         209.49952704203554 / Rest_time :    195.50047295796446 / possible stock :, nan   / possible time :         101.13326335951893
# From : 동대구지사 To : 김해지사
# 누적거리 :    3510.9996384598435 / 누적시간  :         225.30670986767987 / Rest_time :    179.69329013232013  / possible stock :, nan >> 복귀 완료
#
#
#
# VVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVV 3510.9996384598435
# From : 동대구지사 To : DP
# Point_list :  ['DP']
# @@@@@@@@@@@@@@@@@@@@@@@@               check the stopby : (11, 77)
# ---------------------------------------------------------------------------------------------------------------------------------
#
# >> 울산지사
#  >> currrent_p :  울산지사 	current_stock :  nan
# dist :	 77.9518659721367 / fast :	 50.0 / time :	 93.54223916656404
# 누적거리 :    3588.95150443198 / 누적시간  :         103.54223916656404 / time :         93.54223916656404 possible stock :	 nan
# Point_list :  ['DP', '울산지사']
# From : DP To : 울산지사
# 조건 3 207.91552166687188 nan
# Left  0 count : 10 zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz
# dist :    17.154098381987023 / fast :         50.0 / time :         20.584918058384428
# Point list :  ['DP', '울산지사', '울산남구지사']
# 누적거리 :    3606.105602813967 / 누적시간  :         129.12715722494846 / Rest_time :    275.87284277505154 / possible stock :, nan   / possible time :         93.54223916656404
# From : 울산지사 To : 울산남구지사
# 누적거리 :    3669.183167302796 / 누적시간  :         204.82023461154324 / Rest_time :    200.17976538845676  / possible stock :, nan >> 복귀 완료
#
#
#
# VVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVV 3669.183167302796
# From : 울산지사 To : DP
# Point_list :  ['DP']
# @@@@@@@@@@@@@@@@@@@@@@@@               check the stopby : (9, 82)
# ---------------------------------------------------------------------------------------------------------------------------------
#
# >> 부산기장지사
#  >> currrent_p :  부산기장지사 	current_stock :  nan
# dist :	 37.76817363480225 / fast :	 50.0 / time :	 45.321808361762706
# 누적거리 :    3706.951340937598 / 누적시간  :         55.321808361762706 / time :         45.321808361762706 possible stock :	 nan
# Point_list :  ['DP', '부산기장지사']
# From : DP To : 부산기장지사
# 조건 3 304.3563832764746 nan
# Left  0 count : 8 zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz
# dist :    17.93158097659073 / fast :         50.0 / time :         21.517897171908878
# Point list :  ['DP', '부산기장지사', '부산금정지사']
# 누적거리 :    3724.882921914189 / 누적시간  :         81.83970553367158 / Rest_time :    323.1602944663284 / possible stock :, nan   / possible time :         45.321808361762706
# From : 부산기장지사 To : 부산금정지사
# 누적거리 :    3748.853066088709 / 누적시간  :         110.60387854309559 / Rest_time :    294.3961214569044  / possible stock :, nan >> 복귀 완료
#
#
#
# VVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVV 3748.853066088709
# From : 부산기장지사 To : DP
# Point_list :  ['DP']
# @@@@@@@@@@@@@@@@@@@@@@@@               check the stopby : (7, 87)
# ---------------------------------------------------------------------------------------------------------------------------------
#
# >> 부산영도지사(신)
#  >> currrent_p :  부산영도지사(신) 	current_stock :  nan
# dist :	 31.007436301480396 / fast :	 50.0 / time :	 37.20892356177647
# 누적거리 :    3779.8605023901896 / 누적시간  :         47.20892356177647 / time :         37.20892356177647 possible stock :	 nan
# Point_list :  ['DP', '부산영도지사(신)']
# From : DP To : 부산영도지사(신)
# 조건 3 320.582152876447 nan
# Left  0 count : 6 zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz
# dist :    10.969212124979201 / fast :         50.0 / time :         13.16305454997504
# Point list :  ['DP', '부산영도지사(신)', '부산연제지사']
# 누적거리 :    3790.8297145151687 / 누적시간  :         65.37197811175152 / Rest_time :    339.6280218882485 / possible stock :, nan   / possible time :         37.20892356177647
# From : 부산영도지사(신) To : 부산연제지사
# 누적거리 :    3815.919272945348 / 누적시간  :         95.47944822796683 / Rest_time :    309.5205517720332  / possible stock :, nan >> 복귀 완료
#
#
#
# VVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVV 3815.919272945348
# From : 부산영도지사(신) To : DP
# Point_list :  ['DP']
# @@@@@@@@@@@@@@@@@@@@@@@@               check the stopby : (5, 92)
# ---------------------------------------------------------------------------------------------------------------------------------
#
# >> 부산해운대지사
#  >> currrent_p :  부산해운대지사 	current_stock :  nan
# dist :	 29.315660913688074 / fast :	 50.0 / time :	 35.178793096425686
# 누적거리 :    3845.234933859036 / 누적시간  :         45.178793096425686 / time :         35.178793096425686 possible stock :	 nan
# Point_list :  ['DP', '부산해운대지사']
# From : DP To : 부산해운대지사
# 조건 3 324.6424138071486 nan
# Left  0 count : 4 zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz
# dist :    14.357904731566686 / fast :         50.0 / time :         17.229485677880024
# Point list :  ['DP', '부산해운대지사', '부산북구지사']
# 누적거리 :    3859.5928385906027 / 누적시간  :         67.40827877430571 / Rest_time :    337.5917212256943 / possible stock :, nan   / possible time :         35.178793096425686
# From : 부산해운대지사 To : 부산북구지사
# 누적거리 :    3874.5505947727243 / 누적시간  :         85.35758619285139 / Rest_time :    319.6424138071486  / possible stock :, nan >> 복귀 완료
#
#
#
# VVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVV 3874.5505947727243
# From : 부산해운대지사 To : DP
# Point_list :  ['DP']
# @@@@@@@@@@@@@@@@@@@@@@@@               check the stopby : (3, 97)
# ---------------------------------------------------------------------------------------------------------------------------------
#
# >> 양산지사
#  >> currrent_p :  양산지사 	current_stock :  nan
# dist :	 25.463055907442985 / fast :	 50.0 / time :	 30.55566708893158
# 누적거리 :    3900.0136506801673 / 누적시간  :         40.55566708893158 / time :         30.55566708893158 possible stock :	 nan
# Point_list :  ['DP', '양산지사']
# From : DP To : 양산지사
# 조건 3 333.8886658221369 nan
# Left  0 count : 2 zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz
# dist :    24.048643286159795 / fast :         50.0 / time :         28.858371943391756
# Point list :  ['DP', '양산지사', '부산사하지사']
# 누적거리 :    3924.062293966327 / 누적시간  :         74.41403903232333 / Rest_time :    330.58596096767667 / possible stock :, nan   / possible time :         30.55566708893158
# From : 양산지사 To : 부산사하지사
# 누적거리 :    3941.565882234718 / 누적시간  :         95.41834495439262 / Rest_time :    309.58165504560736  / possible stock :, nan >> 복귀 완료
#
#
#
# VVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVV 3941.565882234718
# From : 양산지사 To : DP
# Point_list :  ['DP']
# @@@@@@@@@@@@@@@@@@@@@@@@               check the stopby : (1, 102)
# ---------------------------------------------------------------------------------------------------------------------------------
#
# >> (주)크린토피아 영남지사
#  >> currrent_p :  (주)크린토피아 영남지사 	current_stock :  nan
# dist :	 0.049958176505683516 / fast :	 50.0 / time :	 0.05994981180682022
# 누적거리 :    3941.615840411224 / 누적시간  :         10.05994981180682 / time :         0.05994981180682022 possible stock :	 nan
# Point_list :  ['DP', '(주)크린토피아 영남지사']
# From : DP To : (주)크린토피아 영남지사
# 조건 3 394.8801003763864 nan
# Left  0 count : 0 zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz
#  >>>>>>>>>>>>>>>>>>>>>회차 시 누적 시간 이 360 초과 여서 운행 종료 <<<<<<<<<<<<<<<<<<<<<<<<<<<
#
# VVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVV 3941.615840411224
# From : DP To : DP
# ['No. 1', '특수사업부(영남)', '일', 382.73986457137545, 310.6165538094795, 1, 0, 'DP', '목포지사', None]
# ['No. 2', '특수사업부(영남)', '일', 672.5446153023437, 547.9538460852864, 2, 0, 'DP', '익산지사', '전주지사']
# ['No. 3', '특수사업부(영남)', '일', 587.8489615817728, 477.37413465147733, 2, 0, 'DP', '서광주지사', '광주광산지사']
# ['No. 4', '특수사업부(영남)', '일', 602.4444388097471, 489.53703234145587, 2, 0, 'DP', '광주북구지사', '순천지사']
# ['No. 5', '특수사업부(영남)', '일', 431.37947652658295, 346.98289710548624, 2, 0, 'DP', '여수지사', '진주지사']
# ['No. 6', '특수사업부(영남)', '일', 325.90125945154386, 259.0843828762863, 2, 0, 'DP', '포항북구지사', '포항지사']
# ['No. 7', '특수사업부(영남)', '일', 324.3066544955789, 257.7555454129824, 2, 0, 'DP', '구미지사', '서대구지사']
# ['No. 8', '특수사업부(영남)', '일', 347.5167889997076, 277.0973241664233, 2, 0, 'DP', '안동지사', '대구신평지사 ']
# ['No. 9', '특수사업부(영남)', '일', 252.53230227185944, 197.9435852265492, 2, 0, 'DP', '북대구지사', '남대구지사']
# ['No. 10', '특수사업부(영남)', '일', 220.67849427362006, 171.3987452280171, 2, 0, 'DP', '통영지사', '창원지사']
# ['No. 11', '특수사업부(영남)', '일', 225.30670986767987, 175.25559155639985, 2, 0, 'DP', '동대구지사', '김해지사']
# ['No. 12', '특수사업부(영남)', '일', 204.82023461154324, 158.18352884295246, 2, 0, 'DP', '울산지사', '울산남구지사']
# ['No. 13', '특수사업부(영남)', '일', 110.60387854309559, 79.66989878591312, 2, 0, 'DP', '부산기장지사', '부산금정지사']
# ['No. 14', '특수사업부(영남)', '일', 95.47944822796683, 67.06620685663893, 2, 0, 'DP', '부산영도지사(신)', '부산연제지사']
# ['No. 15', '특수사업부(영남)', '일', 85.35758619285139, 58.63132182737627, 2, 0, 'DP', '부산해운대지사', '부산북구지사']
# ['No. 16', '특수사업부(영남)', '일', 95.41834495439262, 67.01528746199392, 2, 0, 'DP', '양산지사', '부산사하지사']
# ['No. 17', '특수사업부(영남)', '일', 10.05994981180682, 0.04995817650569734, 1, 0, 'DP', '(주)크린토피아 영남지사', None]
# max : 4
# ['Truck Count', 'Region', 'Week', 'Time', 'KM', 'Client Count', 'Client-0', 'Client-1', 'Client-2', 'Client-3']
